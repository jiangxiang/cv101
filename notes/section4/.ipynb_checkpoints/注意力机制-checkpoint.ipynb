# %% [markdown]
# # 注意力机制的语义分割

# %% [markdown]
# ## 什么是注意力机制？
#
# 早期人们对注意力的认知，主要是上下文的关联，或者说是全局性的关联。
#
# 往往，一张图像中像素的语义，不仅仅和周围像素相关，也可能和较远的像素相关。
#
# 然而，受限于卷积的特性，无法从全局层面去观察图像，从而使得像素之间的上下文关联较为薄弱。
#
# 从另一个角度讲，注意力机制的存在一个重要作用，是为了更好的扩大感受野。

# %% [markdown]
# 因此，空洞卷积，从某种程度上来说，可以认为是注意力机制的萌芽。
#
# 同时需要注意的是，注意力机制不仅仅是扩大感受野。同时，包括：
#
# - 过滤不相干信息
#
# - 建模长距离依赖性

# %% [markdown]
# ## 基于注意力机制的模型--PSANet
#
# psanet是较早使用注意力机制的模型。
#
# 在该模型之前，语义分割所面临的主要痛点在于：
#
# 1. 感受野问题。堆叠卷积效果一般，空洞卷积位置固定，难以灵活建模和过滤信息
#
# 2. 上下文信息难以结合。相距较远的像素区域存在强关联，但无法有效的关联起来
#
# 而PSANet针对上述问题的解决方案是：
#
# **利用自注意力机制，学习一个注意力掩膜，从而在特征层面关联建模，来解决局部特征的约束。**

# %% [markdown]
# ### 网络结构
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 其中，X为backbone的输出，经过上路(collect)和下路(distribute)两个分支融合后，得到最终输出。
#
# 以上内容即为注意力模块。

# %% [markdown]
# ### 总体结构
#
# ![image.png](attachment:image.png)

# %% [markdown]
# [代码](https://github.com/cfzd/PSANet_PyTorch/blob/master/PSACUDA/moudles/PSANet.py)

# %% [markdown]
# ## 注意力模型2--DANet
#
# ![image.png](attachment:image.png)

# %% [markdown]
# DANet创新性地将注意力划分成两种类型：
#
#     1. 通道间的注意力
#     2. 通道内的注意力

# %% [markdown]
# 以通道内注意力为例，其基本计算过程如下图所示
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 首先，给定A如下
#
# ![image.png](attachment:image.png)

# %% [markdown]
# B经过reshape之后，得到
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 再转置，得到
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 那么B C矩阵相乘的结果为
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 最后，再乘以D，得到
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 这样，可以看出将同一个通道内的不同位置的信息，融合到了一起。

# %% [markdown]
# 而通道间的注意力map经过类似的处理，得到了下图的结果
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 显然，他可以融合不同通道间的内容。

# %% [markdown]
# [代码](https://github.com/junfu1115/DANet/blob/master/encoding/nn/attention.py)

# %% [markdown]
# ## CCNET：一种十字形的attention模块
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 一种简化计算的注意力机制。
#
# 经过两次十字attention，即可求解全局下的注意力。
#
# ### 网络结构
#
# ![image.png](attachment:image.png)
