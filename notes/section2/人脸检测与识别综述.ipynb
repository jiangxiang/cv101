# %% [markdown]
# # 人脸检测与识别综述

# %% [markdown]
# 人脸检测与识别是计算机视觉和生物识别领域中最受关注的研究内容。
#
# 如何从包含人脸内容的图像、视频等多媒体数据中，找到人脸，并对其身份进行判定，是人脸检测与识别中的主要问题。

# %% [markdown]
# ## 应用场景

# %% [markdown]
# - 安全监控
#
# - 访问控制
#
# - 数据挖掘
#
# 如何将人脸识别与检测技术应用于新的场景，是具有应用创新的工作。

# %% [markdown]
# ## 基本流程
#
# 总体上，人脸检测与识别包含如下几个关键技术步骤：
#
# 1. 人脸检测
#
# 利用目标检测算法，从视频或者图像中检测出所有人脸区域。
#
# 2. 人脸对齐
#
# 将检测到的人脸区域进行对齐，使他们具有相同的尺度、姿态和位置
#
# ![image.png](attachment:image.png)
#
# 3. 特征提取
#
# 从检测得到的特征中提取出特征向量，作为人脸的唯一特征
#
# 4. 特征检索
#
# 将特征与数据库中的特征进行比较，找到最佳匹配

# %% [markdown]
# ## 主要挑战

# %% [markdown]
# 人脸检测与识别在实际应用中，不同的场景具有不同的挑战。
#
# 例如，监控场景下的大规模人群中检测出人脸小目标，是目前学术界主要关心的核心问题之一。
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 在人脸识别中，一些长期存在的、经典的挑战包括
#
# - 头部姿态
#
# - 年龄、妆容的变换
#
# - 光影的变化
#
# - 表情的变换
#
# - 遮挡

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 人脸检测与识别的主要数据集

# %% [markdown]
# ### 人脸检测
#
# | 数据集名称 | 数据规模 | 标签类别 | 链接以及备注 |
# |----------|----------|----------|----------|
# | Pascal Face | 5775张图像，450张包含人脸 | 1074 aeroplanes + 1155 cars + 450 faces + 826 motorbikes + 1370 car backgrounds + 900 general backgrounds | [链接](http://host.robots.ox.ac.uk/pascal/VOC/databases.html) |
# | wider face | 32203张图像，393703张人脸 | 人脸框位置和数量 | [链接](http://shuoyang1213.me/WIDERFACE/) |
# | FDDB | 2854张图片，5171个人脸 | 人脸位置和数量 | [链接](http://vis-www.cs.umass.edu/fddb/) |
#
#
# ### 人脸识别
#
# | 数据集名称 | 数据规模 | 标签类别 | 链接以及备注 |
# |----------|----------|----------|----------|
# | CelebA | 202599张人脸 | 身份信息 | [链接](https://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) |
# | LFW | 13000+图片，1680的人包含2张以上图片 | 位置和身份 | [链接](http://vis-www.cs.umass.edu/lfw/) |

# %% [markdown]
# ## 本章节的主要目标
#
# 1. 了解人脸检测与识别的基本目标，常规流程，以及数学定义
#
# 2. 掌握人脸检测的基本算法和处理方法，理解每个步骤的意义所在
#
# 3. 了解较新的人脸检测与识别算法的基本思路

# %% [markdown]
# ## 本章节的主要架构
#
# - 人脸检测(传统方法)
# - 人脸识别(传统方法)
# - 人脸识别(深度方法)
# - 人脸相关研究拓展(表情检测、3D人脸、动作识别等)
